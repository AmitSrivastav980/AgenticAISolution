# %%
#%pip install python-dotenv  -- this command is for installing dot env module

from dotenv import load_dotenv
from IPython.display import Markdown, display
import os

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!
load_dotenv(override=True)
# Out:
# True

# %%
gemini_api_key = os.getenv("GEMINI_API_KEY")
gemini_base_url = "https://generativelanguage.googleapis.com/v1beta/openai/"

#%pip install openai
from openai import OpenAI
gemini_client = OpenAI(
    base_url=gemini_base_url,
    api_key=gemini_api_key
)
content = "pick a business area that might be worth exploring for an Agentic AI opportunity"
messages = [{"role": "user", "content": content}]

# %%
response = gemini_client.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)
message = response.choices[0].message.content
print(Markdown(response.choices[0].message.content))

# %%
question = "could you please present a pain-point in that industry something challenging that might be ripe for an Agentic solution)"
messages += [{"role": "user", "content": question}]

response = gemini_client.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages)
message = response.choices[0].message.content
print(Markdown(message))
# Out:
# If you observe a perfect mirror reflecting a single light source positioned at an angle such that the reflected image is precisely obscured by the mirror's edge, how many distinct light rays can you definitively say are originating from the light source and reaching your direct line of sight, assuming a perfectly smooth and opaque mirror and ideal point-source illumination?

# %%
question = "could you pleasepropose the Agentic AI solution"
messages += [{"role": "user", "content": question}]

response = gemini_client.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages)
message = response.choices[0].message.content
print(Markdown(message))
# Out:
# If you have three light switches outside a room and three light bulbs inside the room, and you can only enter the room once, how can you determine which switch controls which bulb?

# %%
#%pip install IPython

display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 from IPython.display import Markdown, display
#       2
#       3 #%pip install IPython
#       4
# ----> 5 display(Markdown(response.choices[0].message.content))
#
# NameError: name 'response' is not defined
